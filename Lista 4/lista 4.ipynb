# %% [markdown]
# # Nome: Raylander Marques Melo
# # Matrícula: 586108

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# ...
#   Using cached numpy-2.2.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Using cached numpy-2.2.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...

# %%
import pandas as pd

# %% [markdown]
# # Crie um arquivo Jupyter Notebook e realize as seguintes operações:

# %% [markdown]
# ## a) Ler o dataset fakeTelegram.BR_2022.csv, o qual está disponível no link a seguir: https://drive.google.com/file/d/1c_hLzk85pYw-huHSnFYZM_gn-dUsYRDm/view?usp=drive_link

# %%
# Abre do aquivo CSV e printa alguns elementos
df = pd.read_csv("/home/raylander/Desktop/Introdução a Ciência de Dados/fakeTelegram.BR_2022_tratado.csv")
df
# Out:
#                date_message               id_member_anonymous  \
# 0       2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1       2022-10-05 06:25:08                               NaN
# 2       2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3       2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 4       2022-10-05 06:27:44  cd6979b0b5265f08468fa1689b6300ce
# ...                     ...                               ...
# 557581  2022-11-11 12:06:15  333e9869f23dbd4682d1be382d9c1e59
# 557582  2022-11-11 12:09:08                               NaN
# 557583  2022-11-11 12:09:47                               NaN
# 557584  2022-11-11 12:09:46                               NaN
# 557585  2022-11-11 12:09:48                               NaN
#
#                       id_group_anonymous  \
# 0       12283e08a2eb5789201e105b34489ee7
# 1       12283e08a2eb5789201e105b34489ee7
# 2       9f2d7394334eb224c061c9740b5748fc
# 3       c8f2de56550ed0bf85249608b7ead93d
# ...

# %% [markdown]
# ## b)  Remova os trava-zaps.

# %%
# Soma a quantidade de elementos com True na coluna 'trava_zap' já existente no dataset
print(df['trava_zap'].sum())
# Out:
# 16

# %%
# Retira as linhas que possuem trava-zap
df = df[df['trava_zap'] == False]
# Printa o dataset resultante
df
# Out:
#                date_message               id_member_anonymous  \
# 0       2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1       2022-10-05 06:25:08                               NaN
# 2       2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3       2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 4       2022-10-05 06:27:44  cd6979b0b5265f08468fa1689b6300ce
# ...                     ...                               ...
# 557581  2022-11-11 12:06:15  333e9869f23dbd4682d1be382d9c1e59
# 557582  2022-11-11 12:09:08                               NaN
# 557583  2022-11-11 12:09:47                               NaN
# 557584  2022-11-11 12:09:46                               NaN
# 557585  2022-11-11 12:09:48                               NaN
#
#                       id_group_anonymous  \
# 0       12283e08a2eb5789201e105b34489ee7
# 1       12283e08a2eb5789201e105b34489ee7
# 2       9f2d7394334eb224c061c9740b5748fc
# 3       c8f2de56550ed0bf85249608b7ead93d
# ...

# %% [markdown]
# ## c)  Remover as linhas repetidas (duplicadas).

# %%
df
# Out:
#                date_message               id_member_anonymous  \
# 0       2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1       2022-10-05 06:25:08                               NaN
# 2       2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3       2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 4       2022-10-05 06:27:44  cd6979b0b5265f08468fa1689b6300ce
# ...                     ...                               ...
# 557581  2022-11-11 12:06:15  333e9869f23dbd4682d1be382d9c1e59
# 557582  2022-11-11 12:09:08                               NaN
# 557583  2022-11-11 12:09:47                               NaN
# 557584  2022-11-11 12:09:46                               NaN
# 557585  2022-11-11 12:09:48                               NaN
#
#                       id_group_anonymous  \
# 0       12283e08a2eb5789201e105b34489ee7
# 1       12283e08a2eb5789201e105b34489ee7
# 2       9f2d7394334eb224c061c9740b5748fc
# 3       c8f2de56550ed0bf85249608b7ead93d
# ...

# %%
# Remover linhas duplicadas com base em todas as colunas
df = df.drop_duplicates()
df
# Out:
#                date_message               id_member_anonymous  \
# 0       2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1       2022-10-05 06:25:08                               NaN
# 2       2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3       2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 4       2022-10-05 06:27:44  cd6979b0b5265f08468fa1689b6300ce
# ...                     ...                               ...
# 557581  2022-11-11 12:06:15  333e9869f23dbd4682d1be382d9c1e59
# 557582  2022-11-11 12:09:08                               NaN
# 557583  2022-11-11 12:09:47                               NaN
# 557584  2022-11-11 12:09:46                               NaN
# 557585  2022-11-11 12:09:48                               NaN
#
#                       id_group_anonymous  \
# 0       12283e08a2eb5789201e105b34489ee7
# 1       12283e08a2eb5789201e105b34489ee7
# 2       9f2d7394334eb224c061c9740b5748fc
# 3       c8f2de56550ed0bf85249608b7ead93d
# ...

# %% [markdown]
# ## d)  Remover textos com menos de 5 palavras.

# %%
# Função para contar o número de palavras
def count_words(text):
    if isinstance(text, str):  # Verifica se o valor é uma string
        return len(text.split())
    return 0  # Caso não seja string, retorna 0 palavras

# Adiciona a coluna 'word_count' ao DataFrame
df['word_count'] = df['text_content_anonymous'].apply(count_words)

# Filtra os textos com mais de 5 palavras
df = df[df['word_count'] >= 5]
df
# Out:
#                date_message               id_member_anonymous  \
# 0       2022-10-05 06:25:04  1078cc958f0febe28f4d03207660715f
# 1       2022-10-05 06:25:08                               NaN
# 2       2022-10-05 06:26:28  92a2d8fd7144074f659d1d29dc3751da
# 3       2022-10-05 06:27:28  d60aa38f62b4977426b70944af4aff72
# 5       2022-10-05 06:28:30                               NaN
# ...                     ...                               ...
# 557580  2022-11-11 12:05:41  3e49fd40fd973ee1b8f1a6d58feb4a54
# 557581  2022-11-11 12:06:15  333e9869f23dbd4682d1be382d9c1e59
# 557583  2022-11-11 12:09:47                               NaN
# 557584  2022-11-11 12:09:46                               NaN
# 557585  2022-11-11 12:09:48                               NaN
#
#                       id_group_anonymous  \
# 0       12283e08a2eb5789201e105b34489ee7
# 1       12283e08a2eb5789201e105b34489ee7
# 2       9f2d7394334eb224c061c9740b5748fc
# 3       c8f2de56550ed0bf85249608b7ead93d
# ...

# %% [markdown]
# # Utilizando o PostgreSQL e o Metabase faça as seguintes operações:

# %%
# !pip install sqlalchemy psycopg2
# Out:
# ...
#   Using cached sqlalchemy-2.0.41-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# ...
#   Using cached psycopg2-2.9.10.tar.gz (385 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 5.8 MB/s eta 0:00:004 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.9/603.9 kB 2.1 MB/s eta 0:00:00
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# ...
#   Created wheel for psycopg2: filename=psycopg2-2.9.10-cp312-cp312-linux_x86_64.whl size=529597 sha256=d1d7ebfe9acae34dfd419de2bb1435f0ea9ef1f07e26532e0a89f29de73171fa
#   Stored in directory: /home/raylander/.cache/pip/wheels/ac/bb/ce/afa589c50b6004d3a06fc691e71bd09c9bd5f01e5921e5329b
# Successfully built psycopg2
# ...

# %%
from sqlalchemy import create_engine

usuario = 'raylander'
senha = 'senha'
host = 'localhost'
porta = '5433'
banco = 'meu_banco'

engine = create_engine(f'postgresql+psycopg2://{usuario}:{senha}@{host}:{porta}/{banco}')

df.to_sql('fake_telegram', engine, if_exists='replace', index=False)
# Out:
# 286

# %% [markdown]
# ## a)  Crie dashboards para apresentar:

# %% [markdown]
# ### 1.  As quantidades de grupos, usuários e mensagens;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_1.png)

# %% [markdown]
# ### 2.  A quantidade de mensagens que possuem apenas texto X mídia;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_2_0.png)

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_2_1.png)

# %% [markdown]
# ### 3.  Quantidade de mensagens por tipo de mídia (jpg, mp4 etc);

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_3.png)

# %% [markdown]
# ### 4.  A  relação  entre  a  quantidade  de  mensagens  e  a  quantidade  de  palavras presente nas mensagens;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_4.png)

# %% [markdown]
# ### 5.  Quantidade de mensagens por estado;

# %% [markdown]
# ### 6.  Quantidade de usuários por estado;

# %% [markdown]
# ### 7.  Relação quantidade de usuários por quantidade de mensagens por estado;

# %% [markdown]
# ### 8.  Quantidade de mensagens por país;

# %% [markdown]
# ### 9.  Quantidade de mensagens Brasil X Países Estrangeiros;

# %% [markdown]
# ### 10. As 30 URLs que mais se repetem (mais compartilhadas);

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_10.png)

# %% [markdown]
# ### 11. Os 30 domínios que mais se repetem (mais compartilhados);

# %%
from urllib.parse import urlparse

# Exemplo: df é o seu DataFrame com a coluna 'media_url'
def extrair_dominio(url):
    if pd.isnull(url):
        return None
    try:
        return urlparse(url).netloc
    except:
        return None

# Criar nova coluna com os domínios

df['media_domain'] = df['media_url'].apply(extrair_dominio)
# Out:
# /tmp/ipykernel_4981/2443469279.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['media_domain'] = df['media_url'].apply(extrair_dominio)

# %%
from sqlalchemy import create_engine

usuario = 'raylander'
senha = 'senha'
host = 'localhost'
porta = '5433'
banco = 'meu_banco'

engine = create_engine(f'postgresql+psycopg2://{usuario}:{senha}@{host}:{porta}/{banco}')

df.to_sql('fake_telegram', engine, if_exists='replace', index=False)
# Out:
# 286

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_11.png)

# %% [markdown]
# ### 12. Os 30 usuários mais ativos;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_12.png)

# %% [markdown]
# ### 13. Relação  entre  quantidade  de  mensagens  contendo  somente  texto  e mensagens com tendo mídia dos usuários mais ativos:

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_13.png)

# %% [markdown]
# ### 14. Os 30 usuários que mais compartilharam texto;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_14.png)

# %% [markdown]
# ### 15. Os 30 usuários que mais compartilharam mídias;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_15.png)

# %% [markdown]
# ### 16. As 30 mensagens mais compartilhadas;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_16.png)

# %% [markdown]
# ### 17. As 30 mensagens mais compartilhadas em grupos diferentes;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_17.png)

# %% [markdown]
# ### 18. Mensagens  idênticas  compartilhadas  pelo  mesmo  usuário  (e  suas quantidades);

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_18.png)

# %% [markdown]
# ### 19. Mensagens  idênticas  compartilhadas  pelo  mesmo  usuário  em  grupos distintos (e suas quantidades);

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_19.png)

# %% [markdown]
# ### 20. Os 30 unigramas, bigramas e trigramas mais compartilhados (após a remoção de stop words);

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_20_0.png)

# %% [markdown]
# ### 21. As 30 mensagens mais positivas (distintas);

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_21.png)

# %% [markdown]
# ### 22. As 30 mensagens mais negativas (distintas);

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_22.png)

# %% [markdown]
# ### 23. O usuário mais otimista;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_23.png)

# %% [markdown]
# ### 24. O usuário mais pessimista;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_24.png)

# %% [markdown]
# ### 25. As 30 maiores mensagens;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_25.png)

# %% [markdown]
# ### 26. As 30 menores mensagens;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_26.png)

# %% [markdown]
# ### 27. O dia em que foi publicado a maior quantidade de mensagens;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_27.png)

# %% [markdown]
# ### 28. As mensagens que possuem as palavras “FACÇÃO” e “CRIMINOSA”;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_28.png)

# %% [markdown]
# ### 29. Quantidade de mensagens por dia e hora;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_29.png)

# %% [markdown]
# ### 30. Quantidade de mensagens por hora;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_30.png)

# %% [markdown]
# ### 31. A nuvem de palavras referente às mensagens de texto (após a remoção de stop words);

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_31.png)

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_31_1.png)

# %% [markdown]
# ### 32. A  rede  interativa  das  palavras  referente  às  mensagens  de  texto  (após  a remoção de stop words);

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item)

# %% [markdown]
# ### 33. Proporção de mensagens com e sem URL;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_33.png)

# %% [markdown]
# ### 34. Proporção de desinformação;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_34.png)

# %% [markdown]
# ### 35. Proporção de mensagens contendo mídia e desinformação;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_35.png)

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_35_1.png)

# %% [markdown]
# ### 36. Distribuição de mensagens por score de desinformação;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_34.png)

# %% [markdown]
# ### 37. Proporção de sentimentos;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_37.png)

# %% [markdown]
# ### 38. Distribuição de mensagens por score de sentimentos;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_37.png)

# %% [markdown]
# ### 39. Proporção entre mensagens virais e não virais;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_39,.png)

# %% [markdown]
# ### 40. Algo que você julga importante e que ainda não foi solicitado;

# %% [markdown]
# ![Texto alternativo](../Lista%204/graficos/item_40.png)
